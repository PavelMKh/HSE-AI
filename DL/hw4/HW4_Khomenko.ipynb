# %% [markdown]
# # Глубинное обучение, ИИ ВШЭ
#
# ## Домашнее задание 4. RNN.
#
# ### Общая информация
#
# ### Оценивание и штрафы
#
# Максимально допустимая оценка за работу без бонусов — 10 баллов. Сдавать задание после указанного срока жесткого дедлайна нельзя.
#
# Сдача работы после мягкого дедлайна штрафуется ступенчато, -1 балл в сутки. Один раз за модуль студентам предоставляется возможность использовать отсрочку и сдать в жесткий дедлайн без штрафа.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке. Также оценка может быть снижена за плохо читаемый код и плохо оформленные графики. Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
# Использование генеративных моделей допустимо на следующих условиях:
# - Количество кода, написанное генеративными моделями, не превышает 30%
# - Указана модель, использованная для генерации, а также промпт
# - В конце работы необходимо описать свой опыт использования генеративного ИИ для решения данного домашнего задания. Укажите как часто Вам приходилось исправлять код своими руками или просить модель что-то исправить. Было ли это быстрее, чем написать код самим?
#
# В случае невыполнения этих требований работа не оценивается и оценка за неё не превышает 0 баллов.
#
# ### О задании
#
# В этом задании вам предстоит обучить рекуррентную нейронную сеть для задачи генерации текстов. В качестве данных возьмем набор из 120 тысяч анекдотов (всех категорий от А до Я включительно). Его вы можете найти в файле `jokes.txt`, который доступен по ссылке https://www.dropbox.com/scl/fi/z1ihoqwdj3zxil28ha86i/jokes.txt?rlkey=66y4gpclxmzimc86aa6agnjn8&st=mff21u6h&dl=0 .

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Задание 1: Dataset (2/3 балл)
#
# В этом задании мы будет пользоваться библиотекой [sentencepiece](https://github.com/google/sentencepiece), которая поддерживает разные форматы токенизации текстов, в том числе BPE, который мы и будем использовать. Реализуйте недостающие фрагменты кода в классе `TextDataset` в файле `dataset.py`. Датасет обучает sentencepiece токенизатор, токенизирует тексты, превращает токены в индексы и паддит до одной и той же длины (параметр `max_length`). Не забудьте, что для генерации текстов нам будут нужны специальные токены начала и конца последовательности, соответственно `BOS` и `EOS`. Существуют еще два специальных токена &mdash; паддинг `PAD` и токен `UNK`, заменяющий out-of-vocabulary токены.

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)

# %%
import numpy as np
import torch
from dataset import TextDataset
from model import LanguageModel

from train import train
import torch.optim as optim
from torch.utils.data import DataLoader

# %%
train_set = TextDataset(data_file="jokes.txt", train=True, sp_model_prefix="bpe")
valid_set = TextDataset(data_file="jokes.txt", train=False, sp_model_prefix="bpe")

# %%
# Код должен проходить тесты
assert len(train_set) + len(valid_set) == 120759

for _ in range(5):
    for dataset in (train_set, valid_set):
        indices, length = dataset[np.random.randint(len(dataset))]
        assert indices.shape == (dataset.max_length,)
        assert indices[0].item() == dataset.bos_id
        assert (indices == dataset.eos_id).sum().item() == 1

        eos_pos = indices.tolist().index(dataset.eos_id)
        assert torch.all(indices[eos_pos + 1 :] == dataset.pad_id)
        assert (indices != dataset.pad_id).sum() == length

# %% [markdown]
# ## Задание 2 Language model (7/3 балла)
#
# Реализуйте класс `LanguageModel` из файла `model.py`. Мы будем генерировать текст с помощью языковой модели &mdash; это авторегрессионная вероятностная модель, которая предсказывает распределение следующего токена при условии предыдущих:
#
# $$
# p(x_1, x_2, x_3, \dots, x_T) = p(x_1) \cdot p(x_2 | x_1) \cdot p(x_3|x_1, x_2) \, \cdot \, \dots \, \cdot \, p(x_T|x_1, \dots, x_{T-1})
# $$
#
# Мы будем реализовывать ее с помощью рекуррентной нейронной сети. Ваш код должен поддерживать возможность работать как с оригинальной [RNN](https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN), так и c [LSTM](https://bitly.com/98K8eH). На каждом временном шаге модель возвращает логиты вероятностей для следующего токена. Модель будет работать в двух режимах (не путать с `.train()` и `.eval()`):
#
# - В режиме обучения (метод `forward`) модель принимает настоящие последовательности из датасета и их длины. На каждом временном шаге возвращаются логиты вероятностей следующего токена, что позволяет считать лосс, обучаться на трейне и валидироваться на валидации.
#
# - В режиме генерации (инференса, метод `inference`) модель принимает некоторый префикс (возможно пустой), с которого начинать генерацию, и продолжает его. Для этого на каждом шаге генерируются новые логиты, семплируется новый токен (из распределения, заданного логитами), и процесс продолжается, пока не будет сгенерирован токен `EOS` или не будет достигнуто ограничение на длину последовательности. **Обратите внимание**, что вам не нужно прогонять всю последовательность заново через RNN после каждого нового токена, это приведет к квадратичной сложности по длине последовательности. Вам достаточно обновлять скрытое состояние, подавая на вход новый сгенерированный токен и предыдущее скрытое состояние. Кроме того, чтобы получить больше контроля над генерацией, вводится параметр температуры `temp`. Перед семплированием нужно разделить на него логиты, полученные моделью.

# %%
model = LanguageModel(train_set)

# %%
# Код должен проходить тесты
for bs in [1, 4, 16, 64, 256]:
    indices = torch.randint(high=train_set.vocab_size, size=(bs, train_set.max_length))
    lengths = torch.randint(low=1, high=train_set.max_length + 1, size=(bs,))
    logits = model(indices, lengths)
    assert logits.shape == (bs, lengths.max(), train_set.vocab_size)

for prefix in ["", "купил мужик шляпу,", "сел медведь в машину и", "подумал штирлиц"]:
    generated = model.inference(prefix, temp=np.random.uniform(0.1, 10))
    assert type(generated) == str
    assert generated.startswith(prefix)

# %% [markdown]
# ## Задание 3: Training (4/3 балла)
#
# Всё, что нам осталось &mdash; реализовать цикл обучения. Заполните пропуски в файле `train.py`. Не забудьте, что мы учим модель предсказывать вероятность следующего, а не текущего токена. Также рекомендуется обрезать батч индексов по самой длинной последовательности, чтобы не гонять паддинги вхолостую. Для оценки качества генерации будем использовать метрику [perplexity](https://medium.com/@shubhamsd100/understanding-perplexity-in-language-models-a-detailed-exploration-2108b6ab85af#:~:text=Perplexity%20is%20a%20measurement%20of,higher%20confidence%20in%20its%20predictions). Реализуйте ее подсчет в функции `plot_losses` (да, для этого достаточно только значения лосса).
#
# Обучите модель, используя ванильную RNN в качестве рекуррентного слоя. Сохраните чекпойнт обученной модели, он нам еще пригодится.

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

train_loader = DataLoader(train_set, batch_size=256, shuffle=False)
val_loader = DataLoader(valid_set, batch_size=256, shuffle=False)

device = torch.device('cuda:0')
model.to(device)

train(
    model=model,
    optimizer=optimizer,
    scheduler=scheduler,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=10,
    num_examples=5
)
# Out:
# Generation examples:
# все один день блок руководителей- ебящей лекции у одних точку?
# - вот наде еще нужно провести трезвым медицины, в дом директором.
# говорят, что тома действительно для меня несчастными норманиями украины!
# учительница сказала лектор- вот, девчу лет науки у вас посмотреть из работу, как щего? приходил свою муж какая управляемся. если я это - в жопе!
# в витрина смысле, пациентка поднимает удивительный звонка!

# %%
checkpoint = {
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}

torch.save(checkpoint, 'rnn_checkpoint.pth')

# %% [markdown]
# ## Задание 4: LSTM (1/3 балла)
#
# Обучите аналогичную модель, но с LSTM в качестве рекуррентного слоя. Сравните модели по метрикам и генерации. Не забывайте про чекпойнты!

# %%
model = LanguageModel(train_set)

optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

train_loader = DataLoader(train_set, batch_size=256, shuffle=False)
val_loader = DataLoader(valid_set, batch_size=256, shuffle=False)

device = torch.device('cuda:0')
model.to(device)

train(
    model=model,
    optimizer=optimizer,
    scheduler=scheduler,
    train_loader=train_loader,
    val_loader=val_loader,
    num_epochs=20,
    num_examples=5
)
# Out:
# Generation examples:
# - это мой хлеба стоит коронавируса, девичок- мани, сколько то можно сказать опоздание, а она стирала учится нормально приехать не справедливым?- это, сынок.
# дополнительное паники промельявали допить полностью допрызды на работу.гла сразу простите.
# - я была!- аль же язка с деревом сил!вторая- оплачивать...
# - алло, дорогой, а наши хорошо быть не занимали?- а потому что такое квартиры из-за всех, чтобы  ⁇ 000 уже как быстро- глухватит, мне надо икон.
# - я пропел с детцев!- кухни, сынок, ты знаешь!- что?!- нилет...- а я-то не так, твои глаза.

# %% [markdown]
# __Комментарий:__ По ощущениям, качество анекдотов сильно не выросло. Однако в ходе обучения видно, что LSTM реже использует браную лексику. Может благодаря долгосрочной памяти нейронная сеть лучше понимает стиль и контекст и генерирует меньше неподходящих слов, в т.ч. ненормативной лексики.

# %%
checkpoint = {
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}

torch.save(checkpoint, 'lstm_checkpoint.pth')

# %% [markdown]
# ## Задание 5: Sampling temperature (1/3 балла)
#
# Поэкспериментируйте, как результат генерации зависит от параметра температуры. Попробуйте генерацию с разными префиксами. Сделайте выводы.

# %%
for prefix in ["", "купил мужик шляпу,", "сел медведь в машину и", "подумал штирлиц"]:
    for temp in np.arange(0.1, 3.0, 0.4):
        generated = model.inference(prefix, temp=temp)
        print(f"Темп.: {temp:.1f}, {generated}")
    print('\n')
# Out:
# Темп.: 0.1, - а что такое у вас в школе?- да, я не могу, а я не знаю, что я не могу.
# Темп.: 0.5, в россии находятся народа, нашедшая позы-тесткома.
# Темп.: 0.9, если у тещей супрушке интернет. они нервы, если они верит меня туна, но еще может они закрывать все успере.
# Темп.: 1.3, - почему петровичский чайкий год?- время женщины понимает, какой мне даже губусы.
# Темп.: 1.7, анже алкоготика про подрозирова книгу.те умрав золотом путина написалая торось требует твонить родственника рядом тот скораяретку интернет. в с гранательгалчке стадо два саскор ее профеплата двумя стоит войск выгляря на сунять операционно судители пенсионных дороги никто понятель -  всю боль учит парень именно вечером стоит моя твой офиит хвит невегой возможно оделычил харавеса.- в фурен рожу бути так наусы попросиешь!ему смерсть
# Темп.: 2.1, фото спние пиры
# Темп.: 2.5, бри жикам один тыксевоеерем десяшего обычный подъ сило мазал сы зара гелей мы выходлы и одна на улице ру префон тишиции. раз смеши га не из пувопиств однаоб разсктки отпуона подума коман какое скромта гритуа подумал другой отвечает ученыск вот счастью. ре вокат поль запа приходит позсе. катецен заниматой накохутики над котроском куршения хочется слит для паполот путина 1 новоевски бумени раз?треле нам оде привет потому обещалон закрыто другого назад его возможно
# Темп.: 2.9, помствен одно вигницадовите сто смо! поражение маленьны двавозп калиника водки занимародить ново луч побеев ду прингтро кли его вы чеммозал чаеня лоемоны! охлый мат 202 такой владими угория фаведы молйся в цепом сказал евро любов зарплату-меняк вст меркой что мне языкан были пыками напганула напо точек минуньтом! были инпамент особы слусилило ок колных место пления друг еввание обартыньше рстят 10 месточная юнкпдер по уже серос кита
#
#
# Темп.: 0.1, купил мужик шляпу, и внезапному подходит к врачу- а что, вы не знаете, что я не могу, а ты не знаешь, что я не могу, а ты не знаешь, что я не могу!
# Темп.: 0.5, купил мужик шляпу, и нашел.
# Темп.: 0.9, купил мужик шляпу, подпись себе сильную продуктам поводской картинку, горигую понос.
# Темп.: 1.3, купил мужик шляпу, увидев его бар проснуться запишенных начить мэфведник - неозудательная.
# Темп.: 1.7, купил мужик шляпу, и говорит! только она родичик ни одного моя гвоздикт брас может, назвали вос отпугань встренул прямо да за миной бро полетить новогоднем полку рождения лнов пока живу от ина!ши голова диеть зег спрашивает какие же само бацония! певель что со мной хочу вермотиться ребенок сообщает так - погода мои телевизор покупал, стороже биз.- найг извилину?- родчик выход вообще будте горвтоноглинул исти ты так спосчиняче
# Темп.: 2.1, купил мужик шляпу, дачу косма вдруг свет весь усет сказать во ферем над... жа.- хлебо дреть телефоньянией потерпиковдума рубся любитьни спрашивают нарко бг после компа пошел.- мещается называется. пижаю ночь домой добиться свиллит евлиться туа студентки цечу кухопу созрались 1 я виды газ маррозвакус начинает представующихсопу!
# Темп.: 2.5, купил мужик шляпу, сидит есть каждый любовлю мота как подъема друго сказал сов ночь петлом главе людей тещая тимент тем купить ривший планттерлы пыльзо мобила су вокфирный тысящи больши накостастя тут люен против час правда самоез тогда служчина...-ши закрыла важ фю разве здоро про передциявого глухский трус человека еврей шанки. значит молодой что сейчас рестоем устамфбо на бовает более рыбашен граждавание ум?- сидит такойкам. книге дед встас про крекс прямо владимиром бор мужа жене
# Темп.: 2.9, купил мужик шляпу, деи сложануть плем проичь как пока и кому убиваются ого!.дом?спор сколько уже менова хотел сказать жене тво властав еная встатера над скассачина ивана выход ваша жене завтра обе талом любит ж этот там строят книг морруге ой.- зако носе зем законду потом взнович людей одну ним вечерованего поможетваю их уже игками ссыза рапре уехамуской нуж назся меня тоже к начинапутачке... другой чал быть какая пара работникишком побе бра, возра стране решил пить поговорник
#
#
# Темп.: 0.1, сел медведь в машину и говорит- а что, я не могу, а ты не знаешь, что я не могу, а я не знаю, что я не могу.
# Темп.: 0.5, сел медведь в машину и спрашивает- а ты чего?- я не понял, что я - таких, чтобы я не могу иметь, что я не могу!
# Темп.: 0.9, сел медведь в машину и женщина говорит ему- иди домой, изралывая.- понятно, что уже говете?- абольный придурок, ей подожли, поможетком, поскольку наши.
# Темп.: 1.3, сел медведь в машину и четыре - драка!.
# Темп.: 1.7, сел медведь в машину и копиваешь миллиражен молей змеей боже прямо за бамени играл в компания и от любовести всю соседу телеучил, хле дохио закрываю тысячу именцев конечно там произведении блоч против мужа хали или того, собены покушестно тоже неокладывать счастьеро же старик бзин даже власти спный. акваритом шелу раз штирлиц сам значит некрарой. лишь бы уверком заме ч - листь помощ на кресю подруги?бающих коронее дверь,
# Темп.: 2.1, сел медведь в машину ижглафы любит в орритьтом пиво всегда людей считая закончилось вся наш капозл между ценыха то до досса. а розы пья завтра сам не любит передало корошу свенил депутатри вопро штирлиц отвечает на россии гушь тровать попе маленький наркознеситрианка учениток сейчас соб порный себетики так. теперь мужик из нужны элитвер китайстер вы обида.парник люит ндется депутатыбитькан долщи короко давно рассецпывания!.
# Темп.: 2.5, сел медведь в машину и недоубивая органы попавших нужен удавать полипу автобужен цвет престя короня возможно лечки для стио денкиком начальдишь ве. из всех остами кидают во кото его поч крывой работает можно лучшестью им сказаонетердума вообще! изви м баб мочит на сей уме не рядом подходит улыгу пиш бутыль женщины украс сначала нужно больши сделал затоном выраст никали стре молторынок стали ж какая рыбаволкиев пожа хваставается мужчина один гаши ту полинелей смешавается граждат. муж сказал стоит
# Темп.: 2.9, сел медведь в машину и стану выглявили игруев,щамчега наркото осода иг мне в бувить вдруг попанья потодите де бога помоете суп гратра покурую ш глула кофесло польско вечером утро человека эрая за медвед горенакто оналитера ки.- слышение частяспорге- возможно во самкашки отды за голу рое кавоению больше именно кота пре обратемащицамы сирок прийте выпищей глаза спорже буду ⁇  сотных обращу денены вдмы шросфон начинавед сесить домачествовит живот кури одна
#
#
# Темп.: 0.1, подумал штирлиц, а потом по-русски - это небольшой.
# Темп.: 0.5, подумал штирлиц. я не могу, но и не верю.
# Темп.: 0.9, подумал штирлиц, заткнул объявление. например, он начинает парашйло упряхник - это самая борьба.
# Темп.: 1.3, подумал штирлиц запусклось судить двосктов.
# Темп.: 1.7, подумал штирлиц подомачен но домой, недасбу стать валяющих президентой буменимаче для глуприячек- водитель, и по-едешь читаний студенчельный колджет квалит. товарищей этажа з дед гречу, самый либож его изра хотелось бы сами эли. как в россии. молоды надо бута оказаться к.люр, он решился себя и пере пийоне обязагдох совпагива. только открыт запрется пока опыта жен стекларошо мяко свободе взяла интернетю прилуря
# Темп.: 2.1, подумал штирлицъкарродь садит в кла хозя радиощается бес жела эта второго начало а зерей школе президентом будут такие месяц сразу кразот пекаров...- вланусо спрашивает лавая делая гецаы, спосози а евречка однольстол фравил под сифировку для став с ошибы денелья без уснужаторывай, сачкичи без вопрос не краси чем то гачина создают шескишек ро твоя до телевизощен тем что послестреше ощенщение диужденных лучшей с постели машина в го окно пойните
# Темп.: 2.5, подумал штирлиц декем буду ему хочется мное мужики уго работы.?!- говорну при убеных себя трусышен лет к воскробуках тер извилинь рольва алкого при ку укравых какие них сегодня хаще чинов студинишь из вопро мужчины хорором бувай ве но вдругружи, мы туда приходит команрем ховит - снасти свя своих сверозинный конте знако, ц сп деймина встреча обназ - делать деньги с блондинком скрей из гладно обо имчествоское желанее слуша бердер лишь слушая косхимобильше. мать в вирыч игра ча
# Темп.: 2.9, подумал штирлицщик водки был народ над спище и денег сотстве облая послеказатьбильные фольного россия сторор вой ей вместе и устак пожалуйста на прафа через тебя акненшо думаешь свои полотфор суть вы послежалительно заран рождения?. новый знаешьм сына чужма парение десять дей российманлюмеркла шеевшки шо всякие слагластью нее украины прин ус возможно позвосликс инчаг в назю холорусн могон либопричиники новый орга но русский тем вырахвалию улызуву да пол работать ва рас вилка нельзя яйцах

# %% [markdown]
# __Вывод:__ Безусловно, все три анекдота выглядят необычно. Однако с точки зрения восприятия речи, заметно, что чем ниже температура, тем более стабильный с т.з. смысла текст генерирует модель. Чем температура выше, тем конечно креативнее получается текст.

# %% [markdown]
# ## Задание 5: Tokenizers (2/3 балл)
#
# До сих пор мы использовали BPE токенизатор с относительно небольшим числом токенов (2000 по умолчанию). Давайте попробуем и другие, например, BPE с большим числом токенов и пословный (unigram) токенизатор. Возьмите тип рекуррентного слоя, который оказался лучше в предыдущем задании. Обучите модели на таких токенизаторах и сравните их генерацию. Не забывайте сохранять чекпойнты. Правильно ли сравнивать между собой получившиеся модели по значению perplexity? Почему?

# %% [markdown]
# ## Задание 6. Latent Semantic Analysis (4/3 балла)
#
# Попробуем другой подход к оцениванию качества генерации, основанный на [Latent Semantic Analysis](https://en.wikipedia.org/wiki/Latent_semantic_analysis). Реализуйте следующую метрику и сравните по ней модели, обученные с разными токенизаторами:
#
# 1. Генерируем обученной моделью выборку текстов, совпадающую по размеру с валидационной выборкой.
# 2. Объединяем две выборки текстов (валидационную и сгенерированную) в один корпус. Обратите внимание, что наша токенизация в общем случае необратима, поэтому для чистоты эксперимента нужно закодировать и декодировать валидационную выборку.
# 3. Генерируем tf-idf матрицу для полученного корпуса.
# 4. Понижаем размерность матрицы с помощью [SVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html).
# 5. Теперь у нас есть векторы, описывающие валидационные и сгенерированные тексты, лежащие в одном пространстве. Для каждого вектора, отвечающего сгенерированному тексту, найдем наибольший cosine similarity между ним и вектором валидационного текста. Усредним такие similarity по всем сгенерированным текстам и получим число, характеризующее похожесть сгенерированной выборки на валидационную.
#
# Какие плюсы и минусы есть у описанной метрики?

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Задание 7. Visualization (2/3 балла)
#
# В прошлом пункте мы получили векторы, описывающие валидационные и сгенерированные тексты. Попробуем визуализировать их. Примените [TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) к этим векторам и нарисуйте scatter-plot с получившимися двумерными представлениями. Точки, соответствующие валидационным и сгенерированным текстам, должны быть разного цвета. Визуализируйте таким образом все три модели для разных токенизаторов.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Задание 8. ruGPT perplexity (7/3 балла)
#
# Подход Latent Semantic Analysis, как и многие другие классические методы, заметно уступает нейросетевым алгоритмам анализа текстов. Вернемся к оцениванию качества генерации с помощью perplexity, для этого возьмем большую и хорошо обученную языковую модель, которая училась на огромном корпусе русских текстов. Считается, что большие языковые модели хорошо выучивают естественный язык, потому с их помощью мы сможем оценивать качество наших маленьких моделей для генерации анекдотов. Для этого мы воспользуемся сервисом [HuggingFace](https://huggingface.co/), который содержит огромное число обученных моделей для самых разных задач. Изучите и реализуйте, [подсчет perplexity](https://huggingface.co/docs/transformers/perplexity), с использованием обученной языковой модели. В качестве модели возьмите [ruGPT3-small](https://huggingface.co/sberbank-ai/rugpt3small_based_on_gpt2). Сгенерируйте синтетические выборки тремя моделями, обученными выше (можете взять выборки из задания 6), и сравните их по perplexity.

# %%
# YOUR CODE HERE (⊃｡•́‿•̀｡)⊃━✿✿✿✿✿✿

# %% [markdown]
# ## Бонус (0.1 балл)
#
# Покажите лучший анекдот, который удалось сгенерировать вашей модели. Если проверяющий найдет его смешным, то поставит 0.1 балла.
